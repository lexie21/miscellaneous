# %%
import matplotlib.pyplot as plt
import numpy as np
from random import *

# %%
x = np.array(sample(range(0,10),10))
print(x)
plt.plot(x)
# Out:
# [6 1 8 7 9 5 4 3 0 2]

# %%
import wave #seems too complicated for current task
#today's exercise: implement algo in ODE + do practice problems
